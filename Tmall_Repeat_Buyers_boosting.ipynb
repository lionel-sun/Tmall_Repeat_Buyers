# %%
# 重启
# !kill -9 -1
# 安装包
# !pip install lightgbm

# %%
# 挂载谷歌硬盘 从drive导入数据
from google.colab import drive
drive.mount('/content/drive')
# 创建数据文件夹
# !mkdir /content/dataset
# 复制文件到本地
# !cp -r /content/drive/My\ Drive/Colab_Notebooks/RS6/L11/data_format1_small /content/dataset/data_format1_small
# !cp /content/drive/My\ Drive/Dataset/data_format2.zip /content/dataset/data_format2.zip
# !cp /content/drive/My\ Drive/Dataset/data_format1.zip /content/dataset/data_format1.zip
# 切换当前目录
# %cd /content/dataset/
# 解压缩文件
# !unzip data_format2.zip
# !unzip data_format1.zip
# !unzip ./data_format1_small/data_format1_small.zip
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/dataset
# Archive:  data_format2.zip
#    creating: data_format2/
#   inflating: data_format2/test_format2.csv
#   inflating: data_format2/train_format2.csv
# Archive:  data_format1.zip
#    creating: data_format1/
#   inflating: data_format1/test_format1.csv
#   inflating: data_format1/train_format1.csv
#   inflating: data_format1/user_info_format1.csv
#   inflating: data_format1/user_log_format1.csv

# %% [markdown]
# ### 加载数据

# %%
# 导入包
import pandas as pd
import gc

# %%
# 加载小样本
user_log = pd.read_csv('./data_format1_small/sample_user_log.csv', dtype={'time_stamp':'str'})
user_info = pd.read_csv('./data_format1_small/sample_user_info.csv')
train_data1 = pd.read_csv('./data_format1_small/train.csv')
submission = pd.read_csv('./data_format1_small/test.csv')
train_data = pd.read_csv('./data_format2/train_format2.csv')

# %%
# 加载全量样本
user_log = pd.read_csv('./data_format1/user_log_format1.csv', dtype={'time_stamp':'str'})
user_info = pd.read_csv('./data_format1/user_info_format1.csv')
train_data1 = pd.read_csv('./data_format1/train_format1.csv')
submission = pd.read_csv('./data_format1/test_format1.csv')
train_data = pd.read_csv('./data_format2/train_format2.csv')

# %% [markdown]
# ### 数据预处理

# %%
train_data1['origin'] = 'train'
submission['origin'] = 'test'
matrix = pd.concat([train_data1, submission], ignore_index=True, sort=False)
matrix.drop(['prob'], axis=1, inplace=True)
# 连接user_info表，通过user_id关联
matrix = matrix.merge(user_info, on='user_id', how='left')
# 使用merchant_id（原列名seller_id）
user_log.rename(columns={'seller_id':'merchant_id'}, inplace=True)
matrix
# Out:
#         user_id  merchant_id  label origin  age_range  gender
# 0         34176         3906    0.0  train        6.0     0.0
# 1         34176          121    0.0  train        6.0     0.0
# 2         34176         4356    1.0  train        6.0     0.0
# 3         34176         2217    0.0  train        6.0     0.0
# 4        230784         4818    0.0  train        0.0     0.0
# ...         ...          ...    ...    ...        ...     ...
# 522336   228479         3111    NaN   test        6.0     0.0
# 522337    97919         2341    NaN   test        8.0     1.0
# 522338    97919         3971    NaN   test        8.0     1.0
# 522339    32639         3536    NaN   test        0.0     0.0
# 522340    32639         3319    NaN   test        0.0     0.0
#
# [522341 rows x 6 columns]

# %%
# 格式化
user_log['user_id'] = user_log['user_id'].astype('int32')
user_log['merchant_id'] = user_log['merchant_id'].astype('int32')
user_log['item_id'] = user_log['item_id'].astype('int32')
user_log['cat_id'] = user_log['cat_id'].astype('int32')
user_log['brand_id'].fillna(0, inplace=True)
user_log['brand_id'] = user_log['brand_id'].astype('int32')
user_log['time_stamp'] = pd.to_datetime(user_log['time_stamp'], format='%H%M')
# 1 for <18; 2 for [18,24]; 3 for [25,29]; 4 for [30,34]; 5 for [35,39]; 6 for [40,49]; 7 and 8 for >= 50; 0 and NULL for unknown
matrix['age_range'].fillna(0, inplace=True)
# 0:female, 1:male, 2:unknown
matrix['gender'].fillna(2, inplace=True)
matrix['age_range'] = matrix['age_range'].astype('int8')
matrix['gender'] = matrix['gender'].astype('int8')
matrix['label'] = matrix['label'].astype('str')
matrix['user_id'] = matrix['user_id'].astype('int32')
matrix['merchant_id'] = matrix['merchant_id'].astype('int32')
del user_info, train_data1
gc.collect()
matrix
# Out:
#         user_id  merchant_id label origin  age_range  gender
# 0         34176         3906   0.0  train          6       0
# 1         34176          121   0.0  train          6       0
# 2         34176         4356   1.0  train          6       0
# 3         34176         2217   0.0  train          6       0
# 4        230784         4818   0.0  train          0       0
# ...         ...          ...   ...    ...        ...     ...
# 522336   228479         3111   nan   test          6       0
# 522337    97919         2341   nan   test          8       1
# 522338    97919         3971   nan   test          8       1
# 522339    32639         3536   nan   test          0       0
# 522340    32639         3319   nan   test          0       0
#
# [522341 rows x 6 columns]

# %% [markdown]
# ### 特征处理

# %%
# User特征处理
groups = user_log.groupby(['user_id'])
# 用户交互行为数量 u1
temp = groups.size().reset_index().rename(columns={0:'u1'})
matrix = matrix.merge(temp, on='user_id', how='left')
# 使用agg 基于列的聚合操作，统计唯一值的个数 item_id, cat_id, merchant_id, brand_id
#temp = groups['item_id', 'cat_id', 'merchant_id', 'brand_id'].nunique().reset_index().rename(columns={'item_id':'u2', 'cat_id':'u3', 'merchant_id':'u4', 'brand_id':'u5'})
temp = groups['item_id'].agg([('u2', 'nunique')]).reset_index()
matrix = matrix.merge(temp, on='user_id', how='left')
temp = groups['cat_id'].agg([('u3', 'nunique')]).reset_index()
matrix = matrix.merge(temp, on='user_id', how='left')
temp = groups['merchant_id'].agg([('u4', 'nunique')]).reset_index()
matrix = matrix.merge(temp, on='user_id', how='left')
temp = groups['brand_id'].agg([('u5', 'nunique')]).reset_index()
matrix = matrix.merge(temp, on='user_id', how='left')

# 时间间隔特征 u6 按照小时
temp = groups['time_stamp'].agg([('F_time', 'min'), ('L_time', 'max')]).reset_index()
temp['u6'] = (temp['L_time'] - temp['F_time']).dt.seconds/3600
matrix = matrix.merge(temp[['user_id', 'u6']], on='user_id', how='left')
# 统计操作类型为0，1，2，3的个数
temp = groups['action_type'].value_counts().unstack().reset_index().rename(columns={0:'u7', 1:'u8', 2:'u9', 3:'u10'})
matrix = matrix.merge(temp, on='user_id', how='left')
matrix
# Out:
#         user_id  merchant_id label origin  ...      u7   u8    u9    u10
# 0         34176         3906   0.0  train  ...   410.0  NaN  34.0    7.0
# 1         34176          121   0.0  train  ...   410.0  NaN  34.0    7.0
# 2         34176         4356   1.0  train  ...   410.0  NaN  34.0    7.0
# 3         34176         2217   0.0  train  ...   410.0  NaN  34.0    7.0
# 4        230784         4818   0.0  train  ...    47.0  NaN   7.0    NaN
# ...         ...          ...   ...    ...  ...     ...  ...   ...    ...
# 522336   228479         3111   nan   test  ...  1770.0  NaN  26.0  208.0
# 522337    97919         2341   nan   test  ...    46.0  NaN   8.0    1.0
# 522338    97919         3971   nan   test  ...    46.0  NaN   8.0    1.0
# 522339    32639         3536   nan   test  ...    62.0  1.0   8.0    1.0
# 522340    32639         3319   nan   test  ...    62.0  1.0   8.0    1.0
#
# [522341 rows x 16 columns]

# %%
# 商家特征处理
groups = user_log.groupby(['merchant_id'])
# 商家被交互行为数量 m1
temp = groups.size().reset_index().rename(columns={0:'m1'})
matrix = matrix.merge(temp, on='merchant_id', how='left')
# 统计商家被交互的user_id, item_id, cat_id, brand_id 唯一值
temp = groups['user_id', 'item_id', 'cat_id', 'brand_id'].nunique().reset_index().rename(columns={'user_id':'m2', 'item_id':'m3', 'cat_id':'m4', 'brand_id':'m5'})
matrix = matrix.merge(temp, on='merchant_id', how='left')
# 统计商家被交互的action_type 唯一值
temp = groups['action_type'].value_counts().unstack().reset_index().rename(columns={0:'m6', 1:'m7', 2:'m8', 3:'m9'})
matrix = matrix.merge(temp, on='merchant_id', how='left')
# 按照merchant_id 统计随机负采样的个数
temp = train_data[train_data['label']==-1].groupby(['merchant_id']).size().reset_index().rename(columns={0:'m10'})
matrix = matrix.merge(temp, on='merchant_id', how='left')
matrix
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   import sys
#         user_id  merchant_id label origin  ...   m7_y    m8_y    m9_y   m10
# 0         34176         3906   0.0  train  ...   28.0   410.0   961.0  2861
# 1         34176          121   0.0  train  ...  121.0  4780.0  2699.0  4530
# 2         34176         4356   1.0  train  ...   16.0   963.0   196.0  1088
# 3         34176         2217   0.0  train  ...  101.0  3721.0  4150.0  7268
# 4        230784         4818   0.0  train  ...  129.0  2733.0  1959.0  3102
# ...         ...          ...   ...    ...  ...    ...     ...     ...   ...
# 522336   228479         3111   nan   test  ...    9.0   687.0   412.0  1982
# 522337    97919         2341   nan   test  ...    6.0   815.0   174.0   703
# 522338    97919         3971   nan   test  ...   94.0  2608.0  1588.0  3050
# 522339    32639         3536   nan   test  ...   29.0   793.0   398.0  2177
# 522340    32639         3319   nan   test  ...   34.0  2700.0  1488.0  3607
#
# [522341 rows x 35 columns]

# %%
# 按照user_id, merchant_id分组
groups = user_log.groupby(['user_id', 'merchant_id'])
temp = groups.size().reset_index().rename(columns={0:'um1'}) #统计行为个数
matrix = matrix.merge(temp, on=['user_id', 'merchant_id'], how='left')
temp = groups['item_id', 'cat_id', 'brand_id'].nunique().reset_index().rename(columns={'item_id':'um2', 'cat_id':'um3', 'brand_id':'um4'}) #统计item_id, cat_id, brand_id唯一个数
matrix = matrix.merge(temp, on=['user_id', 'merchant_id'], how='left')
temp = groups['action_type'].value_counts().unstack().reset_index().rename(columns={0:'um5', 1:'um6', 2:'um7', 3:'um8'})#统计不同action_type唯一个数
matrix = matrix.merge(temp, on=['user_id', 'merchant_id'], how='left')
temp = groups['time_stamp'].agg([('first', 'min'), ('last', 'max')]).reset_index()
temp['um9'] = (temp['last'] - temp['first']).dt.seconds/3600
temp.drop(['first', 'last'], axis=1, inplace=True)
matrix = matrix.merge(temp, on=['user_id', 'merchant_id'], how='left') #统计时间间隔
matrix
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """
#         user_id  merchant_id label origin  ...  um6  um7  um8       um9
# 0         34176         3906   0.0  train  ...  NaN  1.0  2.0  0.850000
# 1         34176          121   0.0  train  ...  NaN  1.0  NaN  0.050000
# 2         34176         4356   1.0  train  ...  NaN  6.0  NaN  0.016667
# 3         34176         2217   0.0  train  ...  NaN  1.0  NaN  0.000000
# 4        230784         4818   0.0  train  ...  NaN  1.0  NaN  0.050000
# ...         ...          ...   ...    ...  ...  ...  ...  ...       ...
# 522336   228479         3111   nan   test  ...  NaN  1.0  NaN  0.016667
# 522337    97919         2341   nan   test  ...  NaN  1.0  NaN  0.000000
# 522338    97919         3971   nan   test  ...  NaN  4.0  NaN  0.150000
# 522339    32639         3536   nan   test  ...  NaN  1.0  NaN  0.000000
# 522340    32639         3319   nan   test  ...  NaN  1.0  NaN  0.016667
#
# [522341 rows x 44 columns]

# %%
matrix
# Out:
#         user_id  merchant_id label origin  ...  um7  um8       um9        r1
# 0         34176         3906   0.0  train  ...  1.0  2.0  0.850000  0.082927
# 1         34176          121   0.0  train  ...  1.0  NaN  0.050000  0.082927
# 2         34176         4356   1.0  train  ...  6.0  NaN  0.016667  0.082927
# 3         34176         2217   0.0  train  ...  1.0  NaN  0.000000  0.082927
# 4        230784         4818   0.0  train  ...  1.0  NaN  0.050000  0.148936
# ...         ...          ...   ...    ...  ...  ...  ...       ...       ...
# 522336   228479         3111   nan   test  ...  1.0  NaN  0.016667  0.014689
# 522337    97919         2341   nan   test  ...  1.0  NaN  0.000000  0.173913
# 522338    97919         3971   nan   test  ...  4.0  NaN  0.150000  0.173913
# 522339    32639         3536   nan   test  ...  1.0  NaN  0.000000  0.129032
# 522340    32639         3319   nan   test  ...  1.0  NaN  0.016667  0.129032
#
# [522341 rows x 45 columns]

# %%
#用户购买点击比
matrix['r1'] = matrix['u9']/matrix['u7'] 
#商家购买点击比
# matrix['r2'] = matrix['m8']/matrix['m6'] 
#不同用户不同商家购买点击比
matrix['r3'] = matrix['um7']/matrix['um5']
matrix.fillna(0, inplace=True)
# # 修改age_range字段名称为 age_0, age_1, age_2... age_8
temp = pd.get_dummies(matrix['age_range'], prefix='age')
matrix = pd.concat([matrix, temp], axis=1)
temp = pd.get_dummies(matrix['gender'], prefix='g')
matrix = pd.concat([matrix, temp], axis=1)
matrix.drop(['age_range', 'gender'], axis=1, inplace=True)
matrix
# Out:
#         user_id  merchant_id label origin    u1  ...  age_7  age_8  g_0  g_1  g_2
# 0         34176         3906   0.0  train   451  ...      0      0    1    0    0
# 1         34176          121   0.0  train   451  ...      0      0    1    0    0
# 2         34176         4356   1.0  train   451  ...      0      0    1    0    0
# 3         34176         2217   0.0  train   451  ...      0      0    1    0    0
# 4        230784         4818   0.0  train    54  ...      0      0    1    0    0
# ...         ...          ...   ...    ...   ...  ...    ...    ...  ...  ...  ...
# 522336   228479         3111   nan   test  2004  ...      0      0    1    0    0
# 522337    97919         2341   nan   test    55  ...      0      1    0    1    0
# 522338    97919         3971   nan   test    55  ...      0      1    0    1    0
# 522339    32639         3536   nan   test    72  ...      0      0    1    0    0
# 522340    32639         3319   nan   test    72  ...      0      0    1    0    0
#
# [522341 rows x 56 columns]

# %% [markdown]
# ### 训练集和测试集划分

# %%
# 分割训练数据和测试数据
train_data = matrix[matrix['origin'] == 'train'].drop(['origin'], axis=1)
test_data = matrix[matrix['origin'] == 'test'].drop(['label', 'origin'], axis=1)
train_X, train_y = train_data.drop(['label'], axis=1), train_data['label']
del temp, matrix
gc.collect()
# Out:
# 1555

# %% [markdown]
# ### 模型训练

# %%
# 导入用到的模型包
from sklearn.model_selection import train_test_split
import xgboost as xgb
import lightgbm as lgb
# 将训练集进行切分，20%用于验证
X_train, X_valid, y_train, y_valid = train_test_split(train_X, train_y, test_size=.2)

# %%
# 使用XGBoost
model = xgb.XGBClassifier(
    max_depth=8,
    n_estimators=1000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42     
)
model.fit(
    X_train, y_train,
    eval_metric='auc', 
    eval_set=[(X_train, y_train), (X_valid, y_valid)],
    verbose=True,
    #早停法，如果auc在10epoch没有进步就stop
    early_stopping_rounds=10 
)
model.fit(X_train, y_train)
# Out:
# [0]	validation_0-auc:0.59588	validation_1-auc:0.598048
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.618922	validation_1-auc:0.625476
# [2]	validation_0-auc:0.62867	validation_1-auc:0.6339
# [3]	validation_0-auc:0.627127	validation_1-auc:0.640181
# [4]	validation_0-auc:0.625149	validation_1-auc:0.64167
# [5]	validation_0-auc:0.630772	validation_1-auc:0.651432
# [6]	validation_0-auc:0.631947	validation_1-auc:0.654318
# [7]	validation_0-auc:0.63257	validation_1-auc:0.653732
# [8]	validation_0-auc:0.633137	validation_1-auc:0.650658
# [9]	validation_0-auc:0.631945	validation_1-auc:0.649701
# [10]	validation_0-auc:0.632001	validation_1-auc:0.646786
# [11]	validation_0-auc:0.629908	validation_1-auc:0.643137
# [12]	validation_0-auc:0.62925	validation_1-auc:0.641778
# [13]	validation_0-auc:0.630849	validation_1-auc:0.641225
# [14]	validation_0-auc:0.632077	validation_1-auc:0.645202
# [15]	validation_0-auc:0.631899	validation_1-auc:0.645715
# [16]	validation_0-auc:0.631181	validation_1-auc:0.646019
# Stopping. Best iteration:
# [6]	validation_0-auc:0.631947	validation_1-auc:0.654318
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, eta=0.3, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=8,
#               min_child_weight=300, missing=None, n_estimators=1000, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42,
#               silent=None, subsample=0.8, verbosity=1)

# %%
# 使用LightGBM模型
model = lgb.LGBMClassifier(
    num_leaves=51,
    max_depth=10,
    boosting_type='gbdt',
    objective='binary',
    learning_rate=0.015,
    n_estimators=2000,
    subsample=0.75,
    subsample_freq=2,
    reg_lambda=0.28,
    reg_alpha=0.12,
    colsample_bytree=0.8,
    min_child_samples=300,
    min_split_gain=0.1
)
model.fit(
    X_train, y_train,
    eval_set=[(X_train, y_train), (X_valid, y_valid)],
    eval_metric='auc', 
    early_stopping_rounds=100
)
# Out:
# [1]	training's auc: 0.644572	training's binary_logloss: 0.229872	valid_1's auc: 0.636098	valid_1's binary_logloss: 0.229493
# Training until validation scores don't improve for 100 rounds.
# [2]	training's auc: 0.647401	training's binary_logloss: 0.229549	valid_1's auc: 0.636064	valid_1's binary_logloss: 0.229225
# [3]	training's auc: 0.652825	training's binary_logloss: 0.229232	valid_1's auc: 0.63964	valid_1's binary_logloss: 0.228962
# [4]	training's auc: 0.656787	training's binary_logloss: 0.22893	valid_1's auc: 0.642268	valid_1's binary_logloss: 0.228706
# [5]	training's auc: 0.660627	training's binary_logloss: 0.228675	valid_1's auc: 0.645861	valid_1's binary_logloss: 0.228483
# [6]	training's auc: 0.660755	training's binary_logloss: 0.228414	valid_1's auc: 0.646503	valid_1's binary_logloss: 0.228252
# [7]	training's auc: 0.661864	training's binary_logloss: 0.22815	valid_1's auc: 0.648312	valid_1's binary_logloss: 0.228029
# [8]	training's auc: 0.662586	training's binary_logloss: 0.227902	valid_1's auc: 0.64868	valid_1's binary_logloss: 0.227818
# [9]	training's auc: 0.663851	training's binary_logloss: 0.227646	valid_1's auc: 0.649749	valid_1's binary_logloss: 0.227601
# [10]	training's auc: 0.665262	training's binary_logloss: 0.227403	valid_1's auc: 0.649625	valid_1's binary_logloss: 0.227411
# [11]	training's auc: 0.665191	training's binary_logloss: 0.227179	valid_1's auc: 0.649565	valid_1's binary_logloss: 0.227213
# [12]	training's auc: 0.665605	training's binary_logloss: 0.226949	valid_1's auc: 0.649292	valid_1's binary_logloss: 0.227023
# [13]	training's auc: 0.66564	training's binary_logloss: 0.226737	valid_1's auc: 0.649702	valid_1's binary_logloss: 0.226838
# [14]	training's auc: 0.666	training's binary_logloss: 0.226526	valid_1's auc: 0.649592	valid_1's binary_logloss: 0.226672
# [15]	training's auc: 0.666673	training's binary_logloss: 0.226334	valid_1's auc: 0.650753	valid_1's binary_logloss: 0.226495
# [16]	training's auc: 0.66712	training's binary_logloss: 0.226148	valid_1's auc: 0.651155	valid_1's binary_logloss: 0.226334
# [17]	training's auc: 0.667611	training's binary_logloss: 0.22597	valid_1's auc: 0.651161	valid_1's binary_logloss: 0.226189
# [18]	training's auc: 0.667758	training's binary_logloss: 0.225782	valid_1's auc: 0.650866	valid_1's binary_logloss: 0.22604
# [19]	training's auc: 0.667869	training's binary_logloss: 0.225589	valid_1's auc: 0.651027	valid_1's binary_logloss: 0.22588
# [20]	training's auc: 0.667723	training's binary_logloss: 0.225413	valid_1's auc: 0.650779	valid_1's binary_logloss: 0.225731
# [21]	training's auc: 0.667842	training's binary_logloss: 0.225227	valid_1's auc: 0.651014	valid_1's binary_logloss: 0.225585
# [22]	training's auc: 0.668093	training's binary_logloss: 0.225046	valid_1's auc: 0.651002	valid_1's binary_logloss: 0.225442
# [23]	training's auc: 0.668719	training's binary_logloss: 0.224888	valid_1's auc: 0.651413	valid_1's binary_logloss: 0.225306
# [24]	training's auc: 0.669076	training's binary_logloss: 0.224721	valid_1's auc: 0.651453	valid_1's binary_logloss: 0.225175
# [25]	training's auc: 0.669598	training's binary_logloss: 0.224564	valid_1's auc: 0.651981	valid_1's binary_logloss: 0.225052
# [26]	training's auc: 0.6699	training's binary_logloss: 0.224404	valid_1's auc: 0.652	valid_1's binary_logloss: 0.224929
# [27]	training's auc: 0.670546	training's binary_logloss: 0.224239	valid_1's auc: 0.652227	valid_1's binary_logloss: 0.224802
# [28]	training's auc: 0.670697	training's binary_logloss: 0.224085	valid_1's auc: 0.65231	valid_1's binary_logloss: 0.224679
# [29]	training's auc: 0.671116	training's binary_logloss: 0.223929	valid_1's auc: 0.652725	valid_1's binary_logloss: 0.22455
# [30]	training's auc: 0.671582	training's binary_logloss: 0.223786	valid_1's auc: 0.653253	valid_1's binary_logloss: 0.224427
# [31]	training's auc: 0.672036	training's binary_logloss: 0.223647	valid_1's auc: 0.653758	valid_1's binary_logloss: 0.224314
# [32]	training's auc: 0.672577	training's binary_logloss: 0.223512	valid_1's auc: 0.654314	valid_1's binary_logloss: 0.224201
# [33]	training's auc: 0.672835	training's binary_logloss: 0.223384	valid_1's auc: 0.654402	valid_1's binary_logloss: 0.224098
# [34]	training's auc: 0.67295	training's binary_logloss: 0.22326	valid_1's auc: 0.654433	valid_1's binary_logloss: 0.224006
# [35]	training's auc: 0.673305	training's binary_logloss: 0.223119	valid_1's auc: 0.654724	valid_1's binary_logloss: 0.223896
# [36]	training's auc: 0.673771	training's binary_logloss: 0.222989	valid_1's auc: 0.654697	valid_1's binary_logloss: 0.223803
# [37]	training's auc: 0.674206	training's binary_logloss: 0.222857	valid_1's auc: 0.654998	valid_1's binary_logloss: 0.223697
# [38]	training's auc: 0.674406	training's binary_logloss: 0.222731	valid_1's auc: 0.65503	valid_1's binary_logloss: 0.223602
# [39]	training's auc: 0.674694	training's binary_logloss: 0.222607	valid_1's auc: 0.655211	valid_1's binary_logloss: 0.223504
# [40]	training's auc: 0.674939	training's binary_logloss: 0.222483	valid_1's auc: 0.655418	valid_1's binary_logloss: 0.223415
# [41]	training's auc: 0.675137	training's binary_logloss: 0.222367	valid_1's auc: 0.6553	valid_1's binary_logloss: 0.223323
# [42]	training's auc: 0.675564	training's binary_logloss: 0.222251	valid_1's auc: 0.655293	valid_1's binary_logloss: 0.223245
# [43]	training's auc: 0.675725	training's binary_logloss: 0.222136	valid_1's auc: 0.655414	valid_1's binary_logloss: 0.223155
# [44]	training's auc: 0.675818	training's binary_logloss: 0.222026	valid_1's auc: 0.655404	valid_1's binary_logloss: 0.223069
# [45]	training's auc: 0.676195	training's binary_logloss: 0.221913	valid_1's auc: 0.655645	valid_1's binary_logloss: 0.222978
# [46]	training's auc: 0.676532	training's binary_logloss: 0.221811	valid_1's auc: 0.655749	valid_1's binary_logloss: 0.222893
# [47]	training's auc: 0.67683	training's binary_logloss: 0.221711	valid_1's auc: 0.655773	valid_1's binary_logloss: 0.222825
# [48]	training's auc: 0.677037	training's binary_logloss: 0.221619	valid_1's auc: 0.655811	valid_1's binary_logloss: 0.222761
# [49]	training's auc: 0.677045	training's binary_logloss: 0.221526	valid_1's auc: 0.655746	valid_1's binary_logloss: 0.222697
# [50]	training's auc: 0.677186	training's binary_logloss: 0.221428	valid_1's auc: 0.655794	valid_1's binary_logloss: 0.222632
# [51]	training's auc: 0.677567	training's binary_logloss: 0.221338	valid_1's auc: 0.655925	valid_1's binary_logloss: 0.222571
# [52]	training's auc: 0.677703	training's binary_logloss: 0.221248	valid_1's auc: 0.655886	valid_1's binary_logloss: 0.222513
# [53]	training's auc: 0.678203	training's binary_logloss: 0.221142	valid_1's auc: 0.656338	valid_1's binary_logloss: 0.222426
# [54]	training's auc: 0.678956	training's binary_logloss: 0.22103	valid_1's auc: 0.657025	valid_1's binary_logloss: 0.222332
# [55]	training's auc: 0.679178	training's binary_logloss: 0.220945	valid_1's auc: 0.657193	valid_1's binary_logloss: 0.222273
# [56]	training's auc: 0.67945	training's binary_logloss: 0.22086	valid_1's auc: 0.657295	valid_1's binary_logloss: 0.222215
# [57]	training's auc: 0.67953	training's binary_logloss: 0.22078	valid_1's auc: 0.657286	valid_1's binary_logloss: 0.222163
# [58]	training's auc: 0.679701	training's binary_logloss: 0.220698	valid_1's auc: 0.657364	valid_1's binary_logloss: 0.222107
# [59]	training's auc: 0.679966	training's binary_logloss: 0.220609	valid_1's auc: 0.657455	valid_1's binary_logloss: 0.222046
# [60]	training's auc: 0.680303	training's binary_logloss: 0.220525	valid_1's auc: 0.65756	valid_1's binary_logloss: 0.221992
# [61]	training's auc: 0.680876	training's binary_logloss: 0.220428	valid_1's auc: 0.65788	valid_1's binary_logloss: 0.221916
# [62]	training's auc: 0.681338	training's binary_logloss: 0.220337	valid_1's auc: 0.658013	valid_1's binary_logloss: 0.221864
# [63]	training's auc: 0.681733	training's binary_logloss: 0.220249	valid_1's auc: 0.658023	valid_1's binary_logloss: 0.221813
# [64]	training's auc: 0.682091	training's binary_logloss: 0.220155	valid_1's auc: 0.658154	valid_1's binary_logloss: 0.221752
# [65]	training's auc: 0.682458	training's binary_logloss: 0.220084	valid_1's auc: 0.658166	valid_1's binary_logloss: 0.221708
# [66]	training's auc: 0.682787	training's binary_logloss: 0.220007	valid_1's auc: 0.658258	valid_1's binary_logloss: 0.221657
# [67]	training's auc: 0.683186	training's binary_logloss: 0.219923	valid_1's auc: 0.658352	valid_1's binary_logloss: 0.221601
# [68]	training's auc: 0.683421	training's binary_logloss: 0.219839	valid_1's auc: 0.658458	valid_1's binary_logloss: 0.221545
# [69]	training's auc: 0.683731	training's binary_logloss: 0.219765	valid_1's auc: 0.658754	valid_1's binary_logloss: 0.221492
# [70]	training's auc: 0.684131	training's binary_logloss: 0.219691	valid_1's auc: 0.658909	valid_1's binary_logloss: 0.221447
# [71]	training's auc: 0.684381	training's binary_logloss: 0.219608	valid_1's auc: 0.659073	valid_1's binary_logloss: 0.221382
# [72]	training's auc: 0.684638	training's binary_logloss: 0.219522	valid_1's auc: 0.659268	valid_1's binary_logloss: 0.221322
# [73]	training's auc: 0.68491	training's binary_logloss: 0.219446	valid_1's auc: 0.659324	valid_1's binary_logloss: 0.22128
# [74]	training's auc: 0.685089	training's binary_logloss: 0.21937	valid_1's auc: 0.659434	valid_1's binary_logloss: 0.221226
# [75]	training's auc: 0.685245	training's binary_logloss: 0.219307	valid_1's auc: 0.659567	valid_1's binary_logloss: 0.221183
# [76]	training's auc: 0.685491	training's binary_logloss: 0.219235	valid_1's auc: 0.659753	valid_1's binary_logloss: 0.221138
# [77]	training's auc: 0.685745	training's binary_logloss: 0.219162	valid_1's auc: 0.659979	valid_1's binary_logloss: 0.221084
# [78]	training's auc: 0.686023	training's binary_logloss: 0.219093	valid_1's auc: 0.660079	valid_1's binary_logloss: 0.221041
# [79]	training's auc: 0.686222	training's binary_logloss: 0.219024	valid_1's auc: 0.660233	valid_1's binary_logloss: 0.220996
# [80]	training's auc: 0.686364	training's binary_logloss: 0.218957	valid_1's auc: 0.660356	valid_1's binary_logloss: 0.220949
# [81]	training's auc: 0.686601	training's binary_logloss: 0.21889	valid_1's auc: 0.660449	valid_1's binary_logloss: 0.220913
# [82]	training's auc: 0.686838	training's binary_logloss: 0.21883	valid_1's auc: 0.660517	valid_1's binary_logloss: 0.22088
# [83]	training's auc: 0.687111	training's binary_logloss: 0.218761	valid_1's auc: 0.660512	valid_1's binary_logloss: 0.220837
# [84]	training's auc: 0.687319	training's binary_logloss: 0.218702	valid_1's auc: 0.660535	valid_1's binary_logloss: 0.220814
# [85]	training's auc: 0.687424	training's binary_logloss: 0.218638	valid_1's auc: 0.660571	valid_1's binary_logloss: 0.220775
# [86]	training's auc: 0.687858	training's binary_logloss: 0.218564	valid_1's auc: 0.66097	valid_1's binary_logloss: 0.22072
# [87]	training's auc: 0.68815	training's binary_logloss: 0.218499	valid_1's auc: 0.660985	valid_1's binary_logloss: 0.220693
# [88]	training's auc: 0.688403	training's binary_logloss: 0.218438	valid_1's auc: 0.661106	valid_1's binary_logloss: 0.220658
# [89]	training's auc: 0.688608	training's binary_logloss: 0.218381	valid_1's auc: 0.660983	valid_1's binary_logloss: 0.220641
# [90]	training's auc: 0.688969	training's binary_logloss: 0.218313	valid_1's auc: 0.661139	valid_1's binary_logloss: 0.220601
# [91]	training's auc: 0.689262	training's binary_logloss: 0.218249	valid_1's auc: 0.661435	valid_1's binary_logloss: 0.220557
# [92]	training's auc: 0.689431	training's binary_logloss: 0.218199	valid_1's auc: 0.661518	valid_1's binary_logloss: 0.220531
# [93]	training's auc: 0.689638	training's binary_logloss: 0.218141	valid_1's auc: 0.661623	valid_1's binary_logloss: 0.220498
# [94]	training's auc: 0.689829	training's binary_logloss: 0.218082	valid_1's auc: 0.661717	valid_1's binary_logloss: 0.220462
# [95]	training's auc: 0.690169	training's binary_logloss: 0.218017	valid_1's auc: 0.661971	valid_1's binary_logloss: 0.220415
# [96]	training's auc: 0.690364	training's binary_logloss: 0.217964	valid_1's auc: 0.662047	valid_1's binary_logloss: 0.220384
# [97]	training's auc: 0.690599	training's binary_logloss: 0.217911	valid_1's auc: 0.662095	valid_1's binary_logloss: 0.220354
# [98]	training's auc: 0.690852	training's binary_logloss: 0.217854	valid_1's auc: 0.662256	valid_1's binary_logloss: 0.22032
# [99]	training's auc: 0.691096	training's binary_logloss: 0.217801	valid_1's auc: 0.662325	valid_1's binary_logloss: 0.220293
# [100]	training's auc: 0.691418	training's binary_logloss: 0.217741	valid_1's auc: 0.662502	valid_1's binary_logloss: 0.220255
# [101]	training's auc: 0.691593	training's binary_logloss: 0.217685	valid_1's auc: 0.662611	valid_1's binary_logloss: 0.220215
# [102]	training's auc: 0.691868	training's binary_logloss: 0.217628	valid_1's auc: 0.662813	valid_1's binary_logloss: 0.220177
# [103]	training's auc: 0.692061	training's binary_logloss: 0.217579	valid_1's auc: 0.66277	valid_1's binary_logloss: 0.220153
# [104]	training's auc: 0.692356	training's binary_logloss: 0.217524	valid_1's auc: 0.662886	valid_1's binary_logloss: 0.220125
# [105]	training's auc: 0.692602	training's binary_logloss: 0.217473	valid_1's auc: 0.662919	valid_1's binary_logloss: 0.220103
# [106]	training's auc: 0.692893	training's binary_logloss: 0.217425	valid_1's auc: 0.663039	valid_1's binary_logloss: 0.220085
# [107]	training's auc: 0.69313	training's binary_logloss: 0.217372	valid_1's auc: 0.663119	valid_1's binary_logloss: 0.220058
# [108]	training's auc: 0.693308	training's binary_logloss: 0.217321	valid_1's auc: 0.663217	valid_1's binary_logloss: 0.22003
# [109]	training's auc: 0.693441	training's binary_logloss: 0.217277	valid_1's auc: 0.663231	valid_1's binary_logloss: 0.220012
# [110]	training's auc: 0.693753	training's binary_logloss: 0.217219	valid_1's auc: 0.663558	valid_1's binary_logloss: 0.219968
# [111]	training's auc: 0.693988	training's binary_logloss: 0.217175	valid_1's auc: 0.663665	valid_1's binary_logloss: 0.21995
# [112]	training's auc: 0.694593	training's binary_logloss: 0.217092	valid_1's auc: 0.664195	valid_1's binary_logloss: 0.219891
# [113]	training's auc: 0.694931	training's binary_logloss: 0.21703	valid_1's auc: 0.664339	valid_1's binary_logloss: 0.219854
# [114]	training's auc: 0.695246	training's binary_logloss: 0.21697	valid_1's auc: 0.66441	valid_1's binary_logloss: 0.219825
# [115]	training's auc: 0.695412	training's binary_logloss: 0.216924	valid_1's auc: 0.664389	valid_1's binary_logloss: 0.219811
# [116]	training's auc: 0.69568	training's binary_logloss: 0.216872	valid_1's auc: 0.664595	valid_1's binary_logloss: 0.219781
# [117]	training's auc: 0.695917	training's binary_logloss: 0.21682	valid_1's auc: 0.664653	valid_1's binary_logloss: 0.219752
# [118]	training's auc: 0.696093	training's binary_logloss: 0.21677	valid_1's auc: 0.664813	valid_1's binary_logloss: 0.219722
# [119]	training's auc: 0.69629	training's binary_logloss: 0.216729	valid_1's auc: 0.664768	valid_1's binary_logloss: 0.219712
# [120]	training's auc: 0.696551	training's binary_logloss: 0.216678	valid_1's auc: 0.665031	valid_1's binary_logloss: 0.219677
# [121]	training's auc: 0.696834	training's binary_logloss: 0.216629	valid_1's auc: 0.665092	valid_1's binary_logloss: 0.219656
# [122]	training's auc: 0.697012	training's binary_logloss: 0.216583	valid_1's auc: 0.665177	valid_1's binary_logloss: 0.219629
# [123]	training's auc: 0.697419	training's binary_logloss: 0.216517	valid_1's auc: 0.665396	valid_1's binary_logloss: 0.219588
# [124]	training's auc: 0.697591	training's binary_logloss: 0.216472	valid_1's auc: 0.665454	valid_1's binary_logloss: 0.219563
# [125]	training's auc: 0.697903	training's binary_logloss: 0.216422	valid_1's auc: 0.665677	valid_1's binary_logloss: 0.219537
# [126]	training's auc: 0.698111	training's binary_logloss: 0.216377	valid_1's auc: 0.665723	valid_1's binary_logloss: 0.219519
# [127]	training's auc: 0.698322	training's binary_logloss: 0.216331	valid_1's auc: 0.665742	valid_1's binary_logloss: 0.219497
# [128]	training's auc: 0.698523	training's binary_logloss: 0.216292	valid_1's auc: 0.665686	valid_1's binary_logloss: 0.219486
# [129]	training's auc: 0.698767	training's binary_logloss: 0.216238	valid_1's auc: 0.665835	valid_1's binary_logloss: 0.219456
# [130]	training's auc: 0.698967	training's binary_logloss: 0.216187	valid_1's auc: 0.665969	valid_1's binary_logloss: 0.219428
# [131]	training's auc: 0.699205	training's binary_logloss: 0.216142	valid_1's auc: 0.666021	valid_1's binary_logloss: 0.219408
# [132]	training's auc: 0.699533	training's binary_logloss: 0.216091	valid_1's auc: 0.666145	valid_1's binary_logloss: 0.219386
# [133]	training's auc: 0.699705	training's binary_logloss: 0.216053	valid_1's auc: 0.666163	valid_1's binary_logloss: 0.219371
# [134]	training's auc: 0.699927	training's binary_logloss: 0.216011	valid_1's auc: 0.666211	valid_1's binary_logloss: 0.219352
# [135]	training's auc: 0.70009	training's binary_logloss: 0.215971	valid_1's auc: 0.666178	valid_1's binary_logloss: 0.219343
# [136]	training's auc: 0.700252	training's binary_logloss: 0.21593	valid_1's auc: 0.666154	valid_1's binary_logloss: 0.219331
# [137]	training's auc: 0.70046	training's binary_logloss: 0.215885	valid_1's auc: 0.666182	valid_1's binary_logloss: 0.219314
# [138]	training's auc: 0.700641	training's binary_logloss: 0.215845	valid_1's auc: 0.666211	valid_1's binary_logloss: 0.219298
# [139]	training's auc: 0.700825	training's binary_logloss: 0.215801	valid_1's auc: 0.666275	valid_1's binary_logloss: 0.219284
# [140]	training's auc: 0.700991	training's binary_logloss: 0.215761	valid_1's auc: 0.666317	valid_1's binary_logloss: 0.219268
# [141]	training's auc: 0.701289	training's binary_logloss: 0.215706	valid_1's auc: 0.666589	valid_1's binary_logloss: 0.219234
# [142]	training's auc: 0.701614	training's binary_logloss: 0.215658	valid_1's auc: 0.666812	valid_1's binary_logloss: 0.219205
# [143]	training's auc: 0.701818	training's binary_logloss: 0.215613	valid_1's auc: 0.6668	valid_1's binary_logloss: 0.219192
# [144]	training's auc: 0.702194	training's binary_logloss: 0.215548	valid_1's auc: 0.667104	valid_1's binary_logloss: 0.219147
# [145]	training's auc: 0.702489	training's binary_logloss: 0.215494	valid_1's auc: 0.66732	valid_1's binary_logloss: 0.219114
# [146]	training's auc: 0.702657	training's binary_logloss: 0.215455	valid_1's auc: 0.667399	valid_1's binary_logloss: 0.219093
# [147]	training's auc: 0.702886	training's binary_logloss: 0.215417	valid_1's auc: 0.667382	valid_1's binary_logloss: 0.219083
# [148]	training's auc: 0.703102	training's binary_logloss: 0.215381	valid_1's auc: 0.66747	valid_1's binary_logloss: 0.219068
# [149]	training's auc: 0.703476	training's binary_logloss: 0.215319	valid_1's auc: 0.667791	valid_1's binary_logloss: 0.219019
# [150]	training's auc: 0.703868	training's binary_logloss: 0.215252	valid_1's auc: 0.66808	valid_1's binary_logloss: 0.218971
# [151]	training's auc: 0.704118	training's binary_logloss: 0.215213	valid_1's auc: 0.668075	valid_1's binary_logloss: 0.218958
# [152]	training's auc: 0.70434	training's binary_logloss: 0.215173	valid_1's auc: 0.668116	valid_1's binary_logloss: 0.218941
# [153]	training's auc: 0.704631	training's binary_logloss: 0.215126	valid_1's auc: 0.668348	valid_1's binary_logloss: 0.21891
# [154]	training's auc: 0.704838	training's binary_logloss: 0.215086	valid_1's auc: 0.668433	valid_1's binary_logloss: 0.218896
# [155]	training's auc: 0.705145	training's binary_logloss: 0.215034	valid_1's auc: 0.668702	valid_1's binary_logloss: 0.218861
# [156]	training's auc: 0.705291	training's binary_logloss: 0.214997	valid_1's auc: 0.668725	valid_1's binary_logloss: 0.218849
# [157]	training's auc: 0.70551	training's binary_logloss: 0.214963	valid_1's auc: 0.668775	valid_1's binary_logloss: 0.218838
# [158]	training's auc: 0.705711	training's binary_logloss: 0.214924	valid_1's auc: 0.66889	valid_1's binary_logloss: 0.218822
# [159]	training's auc: 0.705999	training's binary_logloss: 0.214886	valid_1's auc: 0.668955	valid_1's binary_logloss: 0.218808
# [160]	training's auc: 0.706215	training's binary_logloss: 0.214847	valid_1's auc: 0.669034	valid_1's binary_logloss: 0.218788
# [161]	training's auc: 0.706417	training's binary_logloss: 0.214808	valid_1's auc: 0.669101	valid_1's binary_logloss: 0.218776
# [162]	training's auc: 0.706679	training's binary_logloss: 0.214768	valid_1's auc: 0.66921	valid_1's binary_logloss: 0.218759
# [163]	training's auc: 0.706883	training's binary_logloss: 0.214728	valid_1's auc: 0.669312	valid_1's binary_logloss: 0.21874
# [164]	training's auc: 0.707065	training's binary_logloss: 0.214694	valid_1's auc: 0.669336	valid_1's binary_logloss: 0.218731
# [165]	training's auc: 0.707279	training's binary_logloss: 0.214657	valid_1's auc: 0.669459	valid_1's binary_logloss: 0.21871
# [166]	training's auc: 0.707511	training's binary_logloss: 0.214619	valid_1's auc: 0.669605	valid_1's binary_logloss: 0.218692
# [167]	training's auc: 0.707836	training's binary_logloss: 0.214566	valid_1's auc: 0.669812	valid_1's binary_logloss: 0.218663
# [168]	training's auc: 0.708077	training's binary_logloss: 0.214517	valid_1's auc: 0.669972	valid_1's binary_logloss: 0.218636
# [169]	training's auc: 0.708343	training's binary_logloss: 0.21447	valid_1's auc: 0.670182	valid_1's binary_logloss: 0.218609
# [170]	training's auc: 0.708602	training's binary_logloss: 0.214428	valid_1's auc: 0.670297	valid_1's binary_logloss: 0.218592
# [171]	training's auc: 0.708826	training's binary_logloss: 0.21439	valid_1's auc: 0.670451	valid_1's binary_logloss: 0.218574
# [172]	training's auc: 0.708989	training's binary_logloss: 0.214354	valid_1's auc: 0.670549	valid_1's binary_logloss: 0.21856
# [173]	training's auc: 0.709267	training's binary_logloss: 0.214315	valid_1's auc: 0.670538	valid_1's binary_logloss: 0.218553
# [174]	training's auc: 0.709443	training's binary_logloss: 0.214277	valid_1's auc: 0.670609	valid_1's binary_logloss: 0.218535
# [175]	training's auc: 0.709609	training's binary_logloss: 0.214246	valid_1's auc: 0.670669	valid_1's binary_logloss: 0.218523
# [176]	training's auc: 0.709753	training's binary_logloss: 0.214212	valid_1's auc: 0.670706	valid_1's binary_logloss: 0.218506
# [177]	training's auc: 0.710021	training's binary_logloss: 0.214179	valid_1's auc: 0.67076	valid_1's binary_logloss: 0.218498
# [178]	training's auc: 0.710195	training's binary_logloss: 0.214147	valid_1's auc: 0.670818	valid_1's binary_logloss: 0.218489
# [179]	training's auc: 0.710386	training's binary_logloss: 0.214111	valid_1's auc: 0.670873	valid_1's binary_logloss: 0.218472
# [180]	training's auc: 0.710582	training's binary_logloss: 0.214076	valid_1's auc: 0.67093	valid_1's binary_logloss: 0.218455
# [181]	training's auc: 0.710811	training's binary_logloss: 0.214041	valid_1's auc: 0.671024	valid_1's binary_logloss: 0.218444
# [182]	training's auc: 0.711046	training's binary_logloss: 0.214006	valid_1's auc: 0.671048	valid_1's binary_logloss: 0.218438
# [183]	training's auc: 0.711279	training's binary_logloss: 0.213967	valid_1's auc: 0.671142	valid_1's binary_logloss: 0.218422
# [184]	training's auc: 0.711431	training's binary_logloss: 0.213933	valid_1's auc: 0.671257	valid_1's binary_logloss: 0.218408
# [185]	training's auc: 0.711736	training's binary_logloss: 0.213877	valid_1's auc: 0.671581	valid_1's binary_logloss: 0.218365
# [186]	training's auc: 0.712013	training's binary_logloss: 0.213837	valid_1's auc: 0.671703	valid_1's binary_logloss: 0.218346
# [187]	training's auc: 0.712182	training's binary_logloss: 0.2138	valid_1's auc: 0.671681	valid_1's binary_logloss: 0.218333
# [188]	training's auc: 0.712415	training's binary_logloss: 0.213763	valid_1's auc: 0.671714	valid_1's binary_logloss: 0.218319
# [189]	training's auc: 0.712531	training's binary_logloss: 0.213734	valid_1's auc: 0.671738	valid_1's binary_logloss: 0.218306
# [190]	training's auc: 0.712747	training's binary_logloss: 0.213699	valid_1's auc: 0.671738	valid_1's binary_logloss: 0.218296
# [191]	training's auc: 0.713035	training's binary_logloss: 0.213646	valid_1's auc: 0.672012	valid_1's binary_logloss: 0.218259
# [192]	training's auc: 0.713323	training's binary_logloss: 0.213593	valid_1's auc: 0.672274	valid_1's binary_logloss: 0.218222
# [193]	training's auc: 0.713558	training's binary_logloss: 0.213557	valid_1's auc: 0.672309	valid_1's binary_logloss: 0.218211
# [194]	training's auc: 0.713687	training's binary_logloss: 0.213525	valid_1's auc: 0.672304	valid_1's binary_logloss: 0.218204
# [195]	training's auc: 0.71383	training's binary_logloss: 0.213492	valid_1's auc: 0.672331	valid_1's binary_logloss: 0.218196
# [196]	training's auc: 0.713987	training's binary_logloss: 0.213459	valid_1's auc: 0.672349	valid_1's binary_logloss: 0.218187
# [197]	training's auc: 0.714196	training's binary_logloss: 0.213427	valid_1's auc: 0.672377	valid_1's binary_logloss: 0.218177
# [198]	training's auc: 0.714407	training's binary_logloss: 0.213388	valid_1's auc: 0.672452	valid_1's binary_logloss: 0.218167
# [199]	training's auc: 0.714701	training's binary_logloss: 0.213349	valid_1's auc: 0.672674	valid_1's binary_logloss: 0.218144
# [200]	training's auc: 0.715008	training's binary_logloss: 0.213301	valid_1's auc: 0.672912	valid_1's binary_logloss: 0.218114
# [201]	training's auc: 0.715197	training's binary_logloss: 0.213273	valid_1's auc: 0.672933	valid_1's binary_logloss: 0.218104
# [202]	training's auc: 0.715419	training's binary_logloss: 0.213241	valid_1's auc: 0.67297	valid_1's binary_logloss: 0.218089
# [203]	training's auc: 0.715748	training's binary_logloss: 0.213196	valid_1's auc: 0.673185	valid_1's binary_logloss: 0.218063
# [204]	training's auc: 0.715925	training's binary_logloss: 0.213164	valid_1's auc: 0.673326	valid_1's binary_logloss: 0.218043
# [205]	training's auc: 0.716076	training's binary_logloss: 0.213135	valid_1's auc: 0.673473	valid_1's binary_logloss: 0.218027
# [206]	training's auc: 0.716317	training's binary_logloss: 0.213102	valid_1's auc: 0.673471	valid_1's binary_logloss: 0.218021
# [207]	training's auc: 0.716449	training's binary_logloss: 0.21307	valid_1's auc: 0.673552	valid_1's binary_logloss: 0.218007
# [208]	training's auc: 0.716649	training's binary_logloss: 0.213033	valid_1's auc: 0.673685	valid_1's binary_logloss: 0.217988
# [209]	training's auc: 0.716904	training's binary_logloss: 0.212991	valid_1's auc: 0.673858	valid_1's binary_logloss: 0.217963
# [210]	training's auc: 0.717106	training's binary_logloss: 0.212957	valid_1's auc: 0.673844	valid_1's binary_logloss: 0.217957
# [211]	training's auc: 0.717324	training's binary_logloss: 0.21292	valid_1's auc: 0.673902	valid_1's binary_logloss: 0.217943
# [212]	training's auc: 0.7176	training's binary_logloss: 0.212877	valid_1's auc: 0.674047	valid_1's binary_logloss: 0.217923
# [213]	training's auc: 0.717747	training's binary_logloss: 0.212847	valid_1's auc: 0.67411	valid_1's binary_logloss: 0.217913
# [214]	training's auc: 0.717904	training's binary_logloss: 0.212814	valid_1's auc: 0.674129	valid_1's binary_logloss: 0.217906
# [215]	training's auc: 0.71803	training's binary_logloss: 0.212784	valid_1's auc: 0.674188	valid_1's binary_logloss: 0.217898
# [216]	training's auc: 0.718242	training's binary_logloss: 0.212751	valid_1's auc: 0.674268	valid_1's binary_logloss: 0.217885
# [217]	training's auc: 0.718511	training's binary_logloss: 0.212711	valid_1's auc: 0.674385	valid_1's binary_logloss: 0.217866
# [218]	training's auc: 0.718755	training's binary_logloss: 0.212668	valid_1's auc: 0.674562	valid_1's binary_logloss: 0.217843
# [219]	training's auc: 0.718886	training's binary_logloss: 0.21264	valid_1's auc: 0.674665	valid_1's binary_logloss: 0.217829
# [220]	training's auc: 0.719102	training's binary_logloss: 0.212607	valid_1's auc: 0.674787	valid_1's binary_logloss: 0.217811
# [221]	training's auc: 0.71938	training's binary_logloss: 0.212564	valid_1's auc: 0.674897	valid_1's binary_logloss: 0.217791
# [222]	training's auc: 0.719652	training's binary_logloss: 0.212517	valid_1's auc: 0.675126	valid_1's binary_logloss: 0.217759
# [223]	training's auc: 0.719853	training's binary_logloss: 0.212486	valid_1's auc: 0.675063	valid_1's binary_logloss: 0.217761
# [224]	training's auc: 0.720064	training's binary_logloss: 0.212451	valid_1's auc: 0.675025	valid_1's binary_logloss: 0.217754
# [225]	training's auc: 0.720223	training's binary_logloss: 0.212423	valid_1's auc: 0.675063	valid_1's binary_logloss: 0.21775
# [226]	training's auc: 0.720378	training's binary_logloss: 0.212396	valid_1's auc: 0.675088	valid_1's binary_logloss: 0.217748
# [227]	training's auc: 0.720566	training's binary_logloss: 0.212368	valid_1's auc: 0.675107	valid_1's binary_logloss: 0.217738
# [228]	training's auc: 0.720761	training's binary_logloss: 0.212338	valid_1's auc: 0.675174	valid_1's binary_logloss: 0.217725
# [229]	training's auc: 0.720958	training's binary_logloss: 0.212301	valid_1's auc: 0.675319	valid_1's binary_logloss: 0.217708
# [230]	training's auc: 0.721163	training's binary_logloss: 0.212265	valid_1's auc: 0.675479	valid_1's binary_logloss: 0.217682
# [231]	training's auc: 0.72128	training's binary_logloss: 0.212235	valid_1's auc: 0.675498	valid_1's binary_logloss: 0.217679
# [232]	training's auc: 0.721408	training's binary_logloss: 0.212207	valid_1's auc: 0.675535	valid_1's binary_logloss: 0.217673
# [233]	training's auc: 0.7216	training's binary_logloss: 0.21218	valid_1's auc: 0.675565	valid_1's binary_logloss: 0.217664
# [234]	training's auc: 0.721776	training's binary_logloss: 0.212152	valid_1's auc: 0.675556	valid_1's binary_logloss: 0.217662
# [235]	training's auc: 0.722003	training's binary_logloss: 0.212115	valid_1's auc: 0.675702	valid_1's binary_logloss: 0.217642
# [236]	training's auc: 0.722226	training's binary_logloss: 0.212078	valid_1's auc: 0.675844	valid_1's binary_logloss: 0.217623
# [237]	training's auc: 0.722419	training's binary_logloss: 0.212046	valid_1's auc: 0.675875	valid_1's binary_logloss: 0.217617
# [238]	training's auc: 0.722656	training's binary_logloss: 0.212013	valid_1's auc: 0.675931	valid_1's binary_logloss: 0.217608
# [239]	training's auc: 0.722843	training's binary_logloss: 0.211982	valid_1's auc: 0.675973	valid_1's binary_logloss: 0.217603
# [240]	training's auc: 0.723003	training's binary_logloss: 0.211951	valid_1's auc: 0.67604	valid_1's binary_logloss: 0.217593
# [241]	training's auc: 0.72314	training's binary_logloss: 0.211925	valid_1's auc: 0.676134	valid_1's binary_logloss: 0.21758
# [242]	training's auc: 0.723362	training's binary_logloss: 0.21189	valid_1's auc: 0.676213	valid_1's binary_logloss: 0.217568
# [243]	training's auc: 0.723528	training's binary_logloss: 0.21186	valid_1's auc: 0.676267	valid_1's binary_logloss: 0.217559
# [244]	training's auc: 0.723714	training's binary_logloss: 0.211826	valid_1's auc: 0.676302	valid_1's binary_logloss: 0.217549
# [245]	training's auc: 0.723867	training's binary_logloss: 0.211798	valid_1's auc: 0.676272	valid_1's binary_logloss: 0.217546
# [246]	training's auc: 0.724035	training's binary_logloss: 0.21177	valid_1's auc: 0.67625	valid_1's binary_logloss: 0.217542
# [247]	training's auc: 0.724318	training's binary_logloss: 0.211726	valid_1's auc: 0.676485	valid_1's binary_logloss: 0.217518
# [248]	training's auc: 0.724613	training's binary_logloss: 0.211678	valid_1's auc: 0.676731	valid_1's binary_logloss: 0.217487
# [249]	training's auc: 0.724783	training's binary_logloss: 0.21165	valid_1's auc: 0.676731	valid_1's binary_logloss: 0.217484
# [250]	training's auc: 0.724896	training's binary_logloss: 0.211623	valid_1's auc: 0.676729	valid_1's binary_logloss: 0.217484
# [251]	training's auc: 0.725085	training's binary_logloss: 0.211594	valid_1's auc: 0.676694	valid_1's binary_logloss: 0.217481
# [252]	training's auc: 0.725228	training's binary_logloss: 0.211567	valid_1's auc: 0.6767	valid_1's binary_logloss: 0.217478
# [253]	training's auc: 0.725349	training's binary_logloss: 0.211539	valid_1's auc: 0.676699	valid_1's binary_logloss: 0.217478
# [254]	training's auc: 0.725484	training's binary_logloss: 0.211509	valid_1's auc: 0.676709	valid_1's binary_logloss: 0.217471
# [255]	training's auc: 0.725695	training's binary_logloss: 0.211473	valid_1's auc: 0.6768	valid_1's binary_logloss: 0.217455
# [256]	training's auc: 0.725891	training's binary_logloss: 0.211437	valid_1's auc: 0.676888	valid_1's binary_logloss: 0.217437
# [257]	training's auc: 0.726079	training's binary_logloss: 0.211408	valid_1's auc: 0.676863	valid_1's binary_logloss: 0.217431
# [258]	training's auc: 0.726275	training's binary_logloss: 0.211381	valid_1's auc: 0.67688	valid_1's binary_logloss: 0.217428
# [259]	training's auc: 0.726438	training's binary_logloss: 0.211351	valid_1's auc: 0.676913	valid_1's binary_logloss: 0.217424
# [260]	training's auc: 0.726611	training's binary_logloss: 0.211325	valid_1's auc: 0.676909	valid_1's binary_logloss: 0.217421
# [261]	training's auc: 0.726769	training's binary_logloss: 0.211294	valid_1's auc: 0.676866	valid_1's binary_logloss: 0.217422
# [262]	training's auc: 0.726966	training's binary_logloss: 0.211264	valid_1's auc: 0.676808	valid_1's binary_logloss: 0.217424
# [263]	training's auc: 0.727086	training's binary_logloss: 0.211236	valid_1's auc: 0.676849	valid_1's binary_logloss: 0.217414
# [264]	training's auc: 0.727176	training's binary_logloss: 0.21121	valid_1's auc: 0.676866	valid_1's binary_logloss: 0.217406
# [265]	training's auc: 0.727374	training's binary_logloss: 0.211172	valid_1's auc: 0.677014	valid_1's binary_logloss: 0.217384
# [266]	training's auc: 0.727592	training's binary_logloss: 0.211135	valid_1's auc: 0.67717	valid_1's binary_logloss: 0.217363
# [267]	training's auc: 0.727793	training's binary_logloss: 0.211106	valid_1's auc: 0.67731	valid_1's binary_logloss: 0.21735
# [268]	training's auc: 0.727966	training's binary_logloss: 0.211078	valid_1's auc: 0.677424	valid_1's binary_logloss: 0.217339
# [269]	training's auc: 0.728104	training's binary_logloss: 0.211051	valid_1's auc: 0.67745	valid_1's binary_logloss: 0.217333
# [270]	training's auc: 0.728246	training's binary_logloss: 0.211024	valid_1's auc: 0.677474	valid_1's binary_logloss: 0.217328
# [271]	training's auc: 0.728426	training's binary_logloss: 0.210995	valid_1's auc: 0.677487	valid_1's binary_logloss: 0.217321
# [272]	training's auc: 0.728638	training's binary_logloss: 0.210959	valid_1's auc: 0.677594	valid_1's binary_logloss: 0.217306
# [273]	training's auc: 0.728795	training's binary_logloss: 0.210928	valid_1's auc: 0.6777	valid_1's binary_logloss: 0.21729
# [274]	training's auc: 0.728936	training's binary_logloss: 0.210899	valid_1's auc: 0.677762	valid_1's binary_logloss: 0.217276
# [275]	training's auc: 0.729112	training's binary_logloss: 0.21087	valid_1's auc: 0.677786	valid_1's binary_logloss: 0.21727
# [276]	training's auc: 0.729318	training's binary_logloss: 0.210841	valid_1's auc: 0.677832	valid_1's binary_logloss: 0.217265
# [277]	training's auc: 0.729582	training's binary_logloss: 0.210807	valid_1's auc: 0.677908	valid_1's binary_logloss: 0.217256
# [278]	training's auc: 0.729799	training's binary_logloss: 0.210769	valid_1's auc: 0.678018	valid_1's binary_logloss: 0.217241
# [279]	training's auc: 0.72998	training's binary_logloss: 0.21074	valid_1's auc: 0.678044	valid_1's binary_logloss: 0.217238
# [280]	training's auc: 0.730153	training's binary_logloss: 0.210717	valid_1's auc: 0.678069	valid_1's binary_logloss: 0.217235
# [281]	training's auc: 0.730289	training's binary_logloss: 0.210696	valid_1's auc: 0.678083	valid_1's binary_logloss: 0.217231
# [282]	training's auc: 0.730383	training's binary_logloss: 0.210682	valid_1's auc: 0.67806	valid_1's binary_logloss: 0.217231
# [283]	training's auc: 0.73055	training's binary_logloss: 0.210654	valid_1's auc: 0.67807	valid_1's binary_logloss: 0.217225
# [284]	training's auc: 0.730674	training's binary_logloss: 0.210626	valid_1's auc: 0.678122	valid_1's binary_logloss: 0.217216
# [285]	training's auc: 0.730857	training's binary_logloss: 0.2106	valid_1's auc: 0.678092	valid_1's binary_logloss: 0.217216
# [286]	training's auc: 0.731057	training's binary_logloss: 0.210573	valid_1's auc: 0.678103	valid_1's binary_logloss: 0.217215
# [287]	training's auc: 0.731295	training's binary_logloss: 0.21054	valid_1's auc: 0.678113	valid_1's binary_logloss: 0.21721
# [288]	training's auc: 0.731514	training's binary_logloss: 0.210507	valid_1's auc: 0.678157	valid_1's binary_logloss: 0.217204
# [289]	training's auc: 0.731707	training's binary_logloss: 0.210472	valid_1's auc: 0.678238	valid_1's binary_logloss: 0.217192
# [290]	training's auc: 0.731879	training's binary_logloss: 0.210439	valid_1's auc: 0.678322	valid_1's binary_logloss: 0.217179
# [291]	training's auc: 0.732039	training's binary_logloss: 0.210407	valid_1's auc: 0.678422	valid_1's binary_logloss: 0.217164
# [292]	training's auc: 0.732186	training's binary_logloss: 0.210378	valid_1's auc: 0.678479	valid_1's binary_logloss: 0.217154
# [293]	training's auc: 0.732395	training's binary_logloss: 0.21035	valid_1's auc: 0.678507	valid_1's binary_logloss: 0.217146
# [294]	training's auc: 0.732512	training's binary_logloss: 0.210325	valid_1's auc: 0.67852	valid_1's binary_logloss: 0.217142
# [295]	training's auc: 0.73265	training's binary_logloss: 0.210299	valid_1's auc: 0.6785	valid_1's binary_logloss: 0.217143
# [296]	training's auc: 0.732788	training's binary_logloss: 0.210272	valid_1's auc: 0.67852	valid_1's binary_logloss: 0.21714
# [297]	training's auc: 0.732923	training's binary_logloss: 0.210242	valid_1's auc: 0.678562	valid_1's binary_logloss: 0.21713
# [298]	training's auc: 0.733069	training's binary_logloss: 0.210208	valid_1's auc: 0.678649	valid_1's binary_logloss: 0.217115
# [299]	training's auc: 0.733292	training's binary_logloss: 0.210172	valid_1's auc: 0.6788	valid_1's binary_logloss: 0.217092
# [300]	training's auc: 0.733485	training's binary_logloss: 0.210143	valid_1's auc: 0.678903	valid_1's binary_logloss: 0.217079
# [301]	training's auc: 0.733625	training's binary_logloss: 0.210117	valid_1's auc: 0.678931	valid_1's binary_logloss: 0.217075
# [302]	training's auc: 0.733802	training's binary_logloss: 0.210087	valid_1's auc: 0.678973	valid_1's binary_logloss: 0.21707
# [303]	training's auc: 0.733973	training's binary_logloss: 0.210057	valid_1's auc: 0.678957	valid_1's binary_logloss: 0.217066
# [304]	training's auc: 0.734116	training's binary_logloss: 0.210031	valid_1's auc: 0.679017	valid_1's binary_logloss: 0.217057
# [305]	training's auc: 0.734277	training's binary_logloss: 0.210002	valid_1's auc: 0.679032	valid_1's binary_logloss: 0.217053
# [306]	training's auc: 0.734414	training's binary_logloss: 0.209974	valid_1's auc: 0.67903	valid_1's binary_logloss: 0.217049
# [307]	training's auc: 0.734626	training's binary_logloss: 0.209944	valid_1's auc: 0.6791	valid_1's binary_logloss: 0.217039
# [308]	training's auc: 0.734844	training's binary_logloss: 0.209912	valid_1's auc: 0.679128	valid_1's binary_logloss: 0.217031
# [309]	training's auc: 0.734979	training's binary_logloss: 0.209888	valid_1's auc: 0.679127	valid_1's binary_logloss: 0.217031
# [310]	training's auc: 0.735161	training's binary_logloss: 0.20986	valid_1's auc: 0.679182	valid_1's binary_logloss: 0.217022
# [311]	training's auc: 0.735287	training's binary_logloss: 0.209839	valid_1's auc: 0.679187	valid_1's binary_logloss: 0.21702
# [312]	training's auc: 0.735439	training's binary_logloss: 0.209817	valid_1's auc: 0.679264	valid_1's binary_logloss: 0.217011
# [313]	training's auc: 0.735596	training's binary_logloss: 0.209792	valid_1's auc: 0.679234	valid_1's binary_logloss: 0.21701
# [314]	training's auc: 0.735742	training's binary_logloss: 0.209765	valid_1's auc: 0.679189	valid_1's binary_logloss: 0.217012
# [315]	training's auc: 0.735929	training's binary_logloss: 0.209729	valid_1's auc: 0.679354	valid_1's binary_logloss: 0.216992
# [316]	training's auc: 0.736133	training's binary_logloss: 0.209693	valid_1's auc: 0.679471	valid_1's binary_logloss: 0.216974
# [317]	training's auc: 0.736275	training's binary_logloss: 0.209669	valid_1's auc: 0.67945	valid_1's binary_logloss: 0.216972
# [318]	training's auc: 0.736524	training's binary_logloss: 0.209632	valid_1's auc: 0.679562	valid_1's binary_logloss: 0.21696
# [319]	training's auc: 0.736724	training's binary_logloss: 0.209598	valid_1's auc: 0.679608	valid_1's binary_logloss: 0.216954
# [320]	training's auc: 0.736901	training's binary_logloss: 0.209565	valid_1's auc: 0.679608	valid_1's binary_logloss: 0.21695
# [321]	training's auc: 0.737039	training's binary_logloss: 0.209539	valid_1's auc: 0.679639	valid_1's binary_logloss: 0.216944
# [322]	training's auc: 0.737278	training's binary_logloss: 0.209506	valid_1's auc: 0.679705	valid_1's binary_logloss: 0.216936
# [323]	training's auc: 0.737429	training's binary_logloss: 0.209478	valid_1's auc: 0.679781	valid_1's binary_logloss: 0.216926
# [324]	training's auc: 0.73763	training's binary_logloss: 0.209442	valid_1's auc: 0.67985	valid_1's binary_logloss: 0.216914
# [325]	training's auc: 0.737723	training's binary_logloss: 0.209425	valid_1's auc: 0.67984	valid_1's binary_logloss: 0.216916
# [326]	training's auc: 0.737801	training's binary_logloss: 0.209407	valid_1's auc: 0.679826	valid_1's binary_logloss: 0.216916
# [327]	training's auc: 0.737996	training's binary_logloss: 0.209381	valid_1's auc: 0.679825	valid_1's binary_logloss: 0.216915
# [328]	training's auc: 0.7382	training's binary_logloss: 0.209355	valid_1's auc: 0.679828	valid_1's binary_logloss: 0.216913
# [329]	training's auc: 0.738366	training's binary_logloss: 0.20933	valid_1's auc: 0.679824	valid_1's binary_logloss: 0.216914
# [330]	training's auc: 0.738527	training's binary_logloss: 0.209304	valid_1's auc: 0.679852	valid_1's binary_logloss: 0.216911
# [331]	training's auc: 0.738675	training's binary_logloss: 0.209282	valid_1's auc: 0.679852	valid_1's binary_logloss: 0.216907
# [332]	training's auc: 0.738847	training's binary_logloss: 0.209255	valid_1's auc: 0.679866	valid_1's binary_logloss: 0.216902
# [333]	training's auc: 0.738942	training's binary_logloss: 0.209233	valid_1's auc: 0.679881	valid_1's binary_logloss: 0.216898
# [334]	training's auc: 0.739081	training's binary_logloss: 0.209208	valid_1's auc: 0.679889	valid_1's binary_logloss: 0.216898
# [335]	training's auc: 0.739207	training's binary_logloss: 0.209187	valid_1's auc: 0.679893	valid_1's binary_logloss: 0.216895
# [336]	training's auc: 0.73933	training's binary_logloss: 0.209162	valid_1's auc: 0.679893	valid_1's binary_logloss: 0.216889
# [337]	training's auc: 0.739463	training's binary_logloss: 0.209136	valid_1's auc: 0.679925	valid_1's binary_logloss: 0.216881
# [338]	training's auc: 0.73959	training's binary_logloss: 0.209112	valid_1's auc: 0.679901	valid_1's binary_logloss: 0.21688
# [339]	training's auc: 0.739744	training's binary_logloss: 0.209086	valid_1's auc: 0.67991	valid_1's binary_logloss: 0.216878
# [340]	training's auc: 0.7399	training's binary_logloss: 0.209062	valid_1's auc: 0.679958	valid_1's binary_logloss: 0.216873
# [341]	training's auc: 0.740043	training's binary_logloss: 0.209036	valid_1's auc: 0.679963	valid_1's binary_logloss: 0.216873
# [342]	training's auc: 0.74022	training's binary_logloss: 0.209011	valid_1's auc: 0.679897	valid_1's binary_logloss: 0.216877
# [343]	training's auc: 0.740411	training's binary_logloss: 0.208984	valid_1's auc: 0.679824	valid_1's binary_logloss: 0.216883
# [344]	training's auc: 0.740548	training's binary_logloss: 0.208959	valid_1's auc: 0.679868	valid_1's binary_logloss: 0.216875
# [345]	training's auc: 0.740759	training's binary_logloss: 0.208932	valid_1's auc: 0.679862	valid_1's binary_logloss: 0.216874
# [346]	training's auc: 0.740945	training's binary_logloss: 0.208902	valid_1's auc: 0.679899	valid_1's binary_logloss: 0.216864
# [347]	training's auc: 0.74106	training's binary_logloss: 0.208878	valid_1's auc: 0.67995	valid_1's binary_logloss: 0.216854
# [348]	training's auc: 0.74112	training's binary_logloss: 0.208866	valid_1's auc: 0.679937	valid_1's binary_logloss: 0.216854
# [349]	training's auc: 0.741303	training's binary_logloss: 0.208833	valid_1's auc: 0.680028	valid_1's binary_logloss: 0.216839
# [350]	training's auc: 0.741416	training's binary_logloss: 0.208809	valid_1's auc: 0.680027	valid_1's binary_logloss: 0.216836
# [351]	training's auc: 0.741548	training's binary_logloss: 0.208786	valid_1's auc: 0.680008	valid_1's binary_logloss: 0.216836
# [352]	training's auc: 0.741703	training's binary_logloss: 0.208762	valid_1's auc: 0.680059	valid_1's binary_logloss: 0.21683
# [353]	training's auc: 0.741889	training's binary_logloss: 0.208733	valid_1's auc: 0.680065	valid_1's binary_logloss: 0.216826
# [354]	training's auc: 0.742045	training's binary_logloss: 0.208703	valid_1's auc: 0.680089	valid_1's binary_logloss: 0.216822
# [355]	training's auc: 0.742134	training's binary_logloss: 0.208686	valid_1's auc: 0.680058	valid_1's binary_logloss: 0.216823
# [356]	training's auc: 0.742247	training's binary_logloss: 0.208666	valid_1's auc: 0.680024	valid_1's binary_logloss: 0.216823
# [357]	training's auc: 0.742416	training's binary_logloss: 0.20864	valid_1's auc: 0.680043	valid_1's binary_logloss: 0.216821
# [358]	training's auc: 0.742578	training's binary_logloss: 0.208614	valid_1's auc: 0.680068	valid_1's binary_logloss: 0.216817
# [359]	training's auc: 0.742726	training's binary_logloss: 0.20859	valid_1's auc: 0.680058	valid_1's binary_logloss: 0.216815
# [360]	training's auc: 0.74289	training's binary_logloss: 0.208563	valid_1's auc: 0.680083	valid_1's binary_logloss: 0.216811
# [361]	training's auc: 0.742988	training's binary_logloss: 0.208541	valid_1's auc: 0.680124	valid_1's binary_logloss: 0.216805
# [362]	training's auc: 0.743074	training's binary_logloss: 0.208522	valid_1's auc: 0.680171	valid_1's binary_logloss: 0.216798
# [363]	training's auc: 0.7432	training's binary_logloss: 0.208493	valid_1's auc: 0.680232	valid_1's binary_logloss: 0.216787
# [364]	training's auc: 0.743308	training's binary_logloss: 0.208468	valid_1's auc: 0.680247	valid_1's binary_logloss: 0.216782
# [365]	training's auc: 0.743409	training's binary_logloss: 0.208443	valid_1's auc: 0.680251	valid_1's binary_logloss: 0.21678
# [366]	training's auc: 0.743557	training's binary_logloss: 0.208417	valid_1's auc: 0.680283	valid_1's binary_logloss: 0.216774
# [367]	training's auc: 0.743702	training's binary_logloss: 0.208389	valid_1's auc: 0.680302	valid_1's binary_logloss: 0.216771
# [368]	training's auc: 0.743839	training's binary_logloss: 0.208364	valid_1's auc: 0.680301	valid_1's binary_logloss: 0.21677
# [369]	training's auc: 0.743961	training's binary_logloss: 0.208336	valid_1's auc: 0.68041	valid_1's binary_logloss: 0.216754
# [370]	training's auc: 0.744111	training's binary_logloss: 0.208311	valid_1's auc: 0.680409	valid_1's binary_logloss: 0.216752
# [371]	training's auc: 0.744287	training's binary_logloss: 0.208286	valid_1's auc: 0.680405	valid_1's binary_logloss: 0.216755
# [372]	training's auc: 0.744379	training's binary_logloss: 0.20826	valid_1's auc: 0.680397	valid_1's binary_logloss: 0.216754
# [373]	training's auc: 0.744564	training's binary_logloss: 0.208234	valid_1's auc: 0.680388	valid_1's binary_logloss: 0.216754
# [374]	training's auc: 0.744767	training's binary_logloss: 0.208209	valid_1's auc: 0.680378	valid_1's binary_logloss: 0.216755
# [375]	training's auc: 0.744901	training's binary_logloss: 0.208179	valid_1's auc: 0.680474	valid_1's binary_logloss: 0.216743
# [376]	training's auc: 0.745045	training's binary_logloss: 0.208146	valid_1's auc: 0.680618	valid_1's binary_logloss: 0.216726
# [377]	training's auc: 0.745193	training's binary_logloss: 0.208118	valid_1's auc: 0.680664	valid_1's binary_logloss: 0.216715
# [378]	training's auc: 0.745316	training's binary_logloss: 0.208091	valid_1's auc: 0.680709	valid_1's binary_logloss: 0.216705
# [379]	training's auc: 0.745423	training's binary_logloss: 0.208075	valid_1's auc: 0.680697	valid_1's binary_logloss: 0.216702
# [380]	training's auc: 0.745618	training's binary_logloss: 0.208048	valid_1's auc: 0.680768	valid_1's binary_logloss: 0.216697
# [381]	training's auc: 0.745748	training's binary_logloss: 0.208028	valid_1's auc: 0.680764	valid_1's binary_logloss: 0.216695
# [382]	training's auc: 0.745834	training's binary_logloss: 0.208014	valid_1's auc: 0.680757	valid_1's binary_logloss: 0.216695
# ...
# [780]	training's auc: 0.792387	training's binary_logloss: 0.199583	valid_1's auc: 0.684639	valid_1's binary_logloss: 0.215972
# [781]	training's auc: 0.792434	training's binary_logloss: 0.199572	valid_1's auc: 0.684637	valid_1's binary_logloss: 0.215974
# [782]	training's auc: 0.792535	training's binary_logloss: 0.199551	valid_1's auc: 0.684625	valid_1's binary_logloss: 0.215973
# [783]	training's auc: 0.792623	training's binary_logloss: 0.199533	valid_1's auc: 0.684608	valid_1's binary_logloss: 0.215974
# [784]	training's auc: 0.792716	training's binary_logloss: 0.199514	valid_1's auc: 0.684616	valid_1's binary_logloss: 0.215973
# [785]	training's auc: 0.792842	training's binary_logloss: 0.199495	valid_1's auc: 0.684669	valid_1's binary_logloss: 0.215969
# [786]	training's auc: 0.792947	training's binary_logloss: 0.199477	valid_1's auc: 0.684661	valid_1's binary_logloss: 0.215968
# [787]	training's auc: 0.793056	training's binary_logloss: 0.199455	valid_1's auc: 0.684662	valid_1's binary_logloss: 0.215964
# [788]	training's auc: 0.793153	training's binary_logloss: 0.199431	valid_1's auc: 0.684682	valid_1's binary_logloss: 0.21596
# [789]	training's auc: 0.793273	training's binary_logloss: 0.199406	valid_1's auc: 0.684743	valid_1's binary_logloss: 0.215952
# [790]	training's auc: 0.793403	training's binary_logloss: 0.199382	valid_1's auc: 0.684747	valid_1's binary_logloss: 0.215951
# [791]	training's auc: 0.79344	training's binary_logloss: 0.199374	valid_1's auc: 0.68475	valid_1's binary_logloss: 0.215951
# [792]	training's auc: 0.793543	training's binary_logloss: 0.199353	valid_1's auc: 0.684775	valid_1's binary_logloss: 0.215951
# [793]	training's auc: 0.793581	training's binary_logloss: 0.199342	valid_1's auc: 0.684759	valid_1's binary_logloss: 0.21595
# [794]	training's auc: 0.793654	training's binary_logloss: 0.199325	valid_1's auc: 0.68478	valid_1's binary_logloss: 0.215949
# [795]	training's auc: 0.793755	training's binary_logloss: 0.199305	valid_1's auc: 0.68476	valid_1's binary_logloss: 0.21595
# [796]	training's auc: 0.793842	training's binary_logloss: 0.199288	valid_1's auc: 0.684691	valid_1's binary_logloss: 0.215957
# [797]	training's auc: 0.793933	training's binary_logloss: 0.199269	valid_1's auc: 0.684715	valid_1's binary_logloss: 0.215953
# [798]	training's auc: 0.794011	training's binary_logloss: 0.199252	valid_1's auc: 0.684734	valid_1's binary_logloss: 0.21595
# [799]	training's auc: 0.794108	training's binary_logloss: 0.199233	valid_1's auc: 0.684789	valid_1's binary_logloss: 0.215945
# [800]	training's auc: 0.794195	training's binary_logloss: 0.199212	valid_1's auc: 0.684826	valid_1's binary_logloss: 0.21594
# [801]	training's auc: 0.794271	training's binary_logloss: 0.199193	valid_1's auc: 0.684836	valid_1's binary_logloss: 0.21594
# [802]	training's auc: 0.794374	training's binary_logloss: 0.199173	valid_1's auc: 0.684798	valid_1's binary_logloss: 0.215945
# [803]	training's auc: 0.794496	training's binary_logloss: 0.199154	valid_1's auc: 0.684748	valid_1's binary_logloss: 0.215949
# [804]	training's auc: 0.794587	training's binary_logloss: 0.199138	valid_1's auc: 0.684727	valid_1's binary_logloss: 0.215952
# [805]	training's auc: 0.794689	training's binary_logloss: 0.19912	valid_1's auc: 0.684711	valid_1's binary_logloss: 0.215955
# [806]	training's auc: 0.794755	training's binary_logloss: 0.199106	valid_1's auc: 0.684695	valid_1's binary_logloss: 0.215956
# [807]	training's auc: 0.794862	training's binary_logloss: 0.199085	valid_1's auc: 0.684671	valid_1's binary_logloss: 0.215958
# [808]	training's auc: 0.79497	training's binary_logloss: 0.199063	valid_1's auc: 0.684657	valid_1's binary_logloss: 0.215959
# [809]	training's auc: 0.795065	training's binary_logloss: 0.199041	valid_1's auc: 0.684677	valid_1's binary_logloss: 0.215955
# [810]	training's auc: 0.795157	training's binary_logloss: 0.199022	valid_1's auc: 0.684692	valid_1's binary_logloss: 0.215952
# [811]	training's auc: 0.795213	training's binary_logloss: 0.199008	valid_1's auc: 0.684696	valid_1's binary_logloss: 0.215952
# [812]	training's auc: 0.795293	training's binary_logloss: 0.198991	valid_1's auc: 0.684655	valid_1's binary_logloss: 0.215956
# [813]	training's auc: 0.795374	training's binary_logloss: 0.198974	valid_1's auc: 0.684658	valid_1's binary_logloss: 0.215956
# [814]	training's auc: 0.795415	training's binary_logloss: 0.198957	valid_1's auc: 0.684651	valid_1's binary_logloss: 0.215958
# [815]	training's auc: 0.795499	training's binary_logloss: 0.198936	valid_1's auc: 0.68462	valid_1's binary_logloss: 0.215961
# [816]	training's auc: 0.79556	training's binary_logloss: 0.198917	valid_1's auc: 0.684625	valid_1's binary_logloss: 0.21596
# [817]	training's auc: 0.795609	training's binary_logloss: 0.198906	valid_1's auc: 0.684624	valid_1's binary_logloss: 0.215963
# [818]	training's auc: 0.795629	training's binary_logloss: 0.1989	valid_1's auc: 0.684606	valid_1's binary_logloss: 0.215965
# [819]	training's auc: 0.795733	training's binary_logloss: 0.198878	valid_1's auc: 0.684647	valid_1's binary_logloss: 0.21596
# [820]	training's auc: 0.795847	training's binary_logloss: 0.198855	valid_1's auc: 0.684655	valid_1's binary_logloss: 0.21596
# [821]	training's auc: 0.795977	training's binary_logloss: 0.198837	valid_1's auc: 0.684635	valid_1's binary_logloss: 0.215962
# [822]	training's auc: 0.79609	training's binary_logloss: 0.198821	valid_1's auc: 0.684606	valid_1's binary_logloss: 0.215965
# [823]	training's auc: 0.796211	training's binary_logloss: 0.198801	valid_1's auc: 0.68462	valid_1's binary_logloss: 0.215964
# [824]	training's auc: 0.796316	training's binary_logloss: 0.198781	valid_1's auc: 0.684627	valid_1's binary_logloss: 0.215963
# [825]	training's auc: 0.796404	training's binary_logloss: 0.198762	valid_1's auc: 0.684667	valid_1's binary_logloss: 0.21596
# [826]	training's auc: 0.796488	training's binary_logloss: 0.198743	valid_1's auc: 0.684724	valid_1's binary_logloss: 0.215953
# [827]	training's auc: 0.796568	training's binary_logloss: 0.198726	valid_1's auc: 0.684711	valid_1's binary_logloss: 0.215956
# [828]	training's auc: 0.79665	training's binary_logloss: 0.198708	valid_1's auc: 0.684682	valid_1's binary_logloss: 0.215958
# [829]	training's auc: 0.796752	training's binary_logloss: 0.19869	valid_1's auc: 0.684675	valid_1's binary_logloss: 0.21596
# [830]	training's auc: 0.79686	training's binary_logloss: 0.198671	valid_1's auc: 0.684687	valid_1's binary_logloss: 0.215958
# [831]	training's auc: 0.796947	training's binary_logloss: 0.19865	valid_1's auc: 0.684667	valid_1's binary_logloss: 0.215959
# [832]	training's auc: 0.797041	training's binary_logloss: 0.198631	valid_1's auc: 0.684671	valid_1's binary_logloss: 0.215959
# [833]	training's auc: 0.797187	training's binary_logloss: 0.198607	valid_1's auc: 0.684645	valid_1's binary_logloss: 0.215961
# [834]	training's auc: 0.797219	training's binary_logloss: 0.198597	valid_1's auc: 0.684648	valid_1's binary_logloss: 0.215962
# [835]	training's auc: 0.797265	training's binary_logloss: 0.198582	valid_1's auc: 0.684657	valid_1's binary_logloss: 0.215964
# [836]	training's auc: 0.797323	training's binary_logloss: 0.198567	valid_1's auc: 0.68464	valid_1's binary_logloss: 0.215968
# [837]	training's auc: 0.797412	training's binary_logloss: 0.198548	valid_1's auc: 0.684658	valid_1's binary_logloss: 0.215966
# [838]	training's auc: 0.797495	training's binary_logloss: 0.198528	valid_1's auc: 0.684643	valid_1's binary_logloss: 0.215968
# [839]	training's auc: 0.797561	training's binary_logloss: 0.198512	valid_1's auc: 0.684625	valid_1's binary_logloss: 0.215971
# [840]	training's auc: 0.797619	training's binary_logloss: 0.198498	valid_1's auc: 0.68463	valid_1's binary_logloss: 0.215973
# [841]	training's auc: 0.79776	training's binary_logloss: 0.198474	valid_1's auc: 0.684615	valid_1's binary_logloss: 0.215973
# [842]	training's auc: 0.797905	training's binary_logloss: 0.19845	valid_1's auc: 0.684605	valid_1's binary_logloss: 0.215973
# [843]	training's auc: 0.797987	training's binary_logloss: 0.198431	valid_1's auc: 0.684629	valid_1's binary_logloss: 0.215972
# [844]	training's auc: 0.79808	training's binary_logloss: 0.198412	valid_1's auc: 0.68463	valid_1's binary_logloss: 0.215973
# [845]	training's auc: 0.798172	training's binary_logloss: 0.198394	valid_1's auc: 0.684621	valid_1's binary_logloss: 0.215975
# [846]	training's auc: 0.798211	training's binary_logloss: 0.198382	valid_1's auc: 0.68463	valid_1's binary_logloss: 0.215975
# [847]	training's auc: 0.798303	training's binary_logloss: 0.198364	valid_1's auc: 0.684601	valid_1's binary_logloss: 0.215979
# [848]	training's auc: 0.798397	training's binary_logloss: 0.198344	valid_1's auc: 0.684606	valid_1's binary_logloss: 0.215979
# [849]	training's auc: 0.798501	training's binary_logloss: 0.198326	valid_1's auc: 0.684648	valid_1's binary_logloss: 0.215974
# [850]	training's auc: 0.798616	training's binary_logloss: 0.198304	valid_1's auc: 0.684642	valid_1's binary_logloss: 0.215973
# [851]	training's auc: 0.798714	training's binary_logloss: 0.198284	valid_1's auc: 0.684655	valid_1's binary_logloss: 0.215971
# [852]	training's auc: 0.798812	training's binary_logloss: 0.198265	valid_1's auc: 0.684663	valid_1's binary_logloss: 0.215971
# [853]	training's auc: 0.798907	training's binary_logloss: 0.198245	valid_1's auc: 0.684645	valid_1's binary_logloss: 0.215972
# [854]	training's auc: 0.799009	training's binary_logloss: 0.198222	valid_1's auc: 0.684633	valid_1's binary_logloss: 0.215972
# [855]	training's auc: 0.799127	training's binary_logloss: 0.198203	valid_1's auc: 0.684614	valid_1's binary_logloss: 0.215974
# [856]	training's auc: 0.799237	training's binary_logloss: 0.198185	valid_1's auc: 0.684648	valid_1's binary_logloss: 0.215971
# [857]	training's auc: 0.799328	training's binary_logloss: 0.198166	valid_1's auc: 0.68462	valid_1's binary_logloss: 0.215976
# [858]	training's auc: 0.79943	training's binary_logloss: 0.198147	valid_1's auc: 0.684618	valid_1's binary_logloss: 0.215977
# [859]	training's auc: 0.7995	training's binary_logloss: 0.198129	valid_1's auc: 0.684608	valid_1's binary_logloss: 0.215979
# [860]	training's auc: 0.79962	training's binary_logloss: 0.198107	valid_1's auc: 0.684611	valid_1's binary_logloss: 0.215978
# [861]	training's auc: 0.799714	training's binary_logloss: 0.198088	valid_1's auc: 0.684598	valid_1's binary_logloss: 0.215981
# [862]	training's auc: 0.799832	training's binary_logloss: 0.198069	valid_1's auc: 0.684595	valid_1's binary_logloss: 0.21598
# [863]	training's auc: 0.799936	training's binary_logloss: 0.198047	valid_1's auc: 0.684607	valid_1's binary_logloss: 0.215979
# [864]	training's auc: 0.800017	training's binary_logloss: 0.198029	valid_1's auc: 0.684599	valid_1's binary_logloss: 0.215981
# [865]	training's auc: 0.800103	training's binary_logloss: 0.198013	valid_1's auc: 0.684584	valid_1's binary_logloss: 0.215984
# [866]	training's auc: 0.800199	training's binary_logloss: 0.197996	valid_1's auc: 0.684597	valid_1's binary_logloss: 0.21598
# [867]	training's auc: 0.800316	training's binary_logloss: 0.197977	valid_1's auc: 0.684635	valid_1's binary_logloss: 0.215978
# [868]	training's auc: 0.800424	training's binary_logloss: 0.197959	valid_1's auc: 0.6846	valid_1's binary_logloss: 0.21598
# [869]	training's auc: 0.80051	training's binary_logloss: 0.197942	valid_1's auc: 0.684592	valid_1's binary_logloss: 0.21598
# [870]	training's auc: 0.80061	training's binary_logloss: 0.197919	valid_1's auc: 0.684589	valid_1's binary_logloss: 0.215978
# [871]	training's auc: 0.80064	training's binary_logloss: 0.19791	valid_1's auc: 0.684625	valid_1's binary_logloss: 0.215973
# [872]	training's auc: 0.800683	training's binary_logloss: 0.1979	valid_1's auc: 0.684648	valid_1's binary_logloss: 0.21597
# [873]	training's auc: 0.800795	training's binary_logloss: 0.197882	valid_1's auc: 0.684656	valid_1's binary_logloss: 0.215968
# [874]	training's auc: 0.800853	training's binary_logloss: 0.197873	valid_1's auc: 0.684662	valid_1's binary_logloss: 0.215967
# [875]	training's auc: 0.800927	training's binary_logloss: 0.197856	valid_1's auc: 0.68465	valid_1's binary_logloss: 0.21597
# [876]	training's auc: 0.80097	training's binary_logloss: 0.197841	valid_1's auc: 0.6846	valid_1's binary_logloss: 0.215978
# [877]	training's auc: 0.801055	training's binary_logloss: 0.197826	valid_1's auc: 0.684607	valid_1's binary_logloss: 0.215977
# [878]	training's auc: 0.801145	training's binary_logloss: 0.197807	valid_1's auc: 0.684593	valid_1's binary_logloss: 0.215978
# [879]	training's auc: 0.801235	training's binary_logloss: 0.197787	valid_1's auc: 0.684605	valid_1's binary_logloss: 0.215974
# [880]	training's auc: 0.801344	training's binary_logloss: 0.197769	valid_1's auc: 0.684614	valid_1's binary_logloss: 0.215975
# [881]	training's auc: 0.801415	training's binary_logloss: 0.197753	valid_1's auc: 0.684599	valid_1's binary_logloss: 0.215976
# [882]	training's auc: 0.801496	training's binary_logloss: 0.197736	valid_1's auc: 0.684633	valid_1's binary_logloss: 0.215973
# [883]	training's auc: 0.801562	training's binary_logloss: 0.197718	valid_1's auc: 0.684645	valid_1's binary_logloss: 0.215971
# [884]	training's auc: 0.801653	training's binary_logloss: 0.197696	valid_1's auc: 0.684689	valid_1's binary_logloss: 0.215964
# [885]	training's auc: 0.80177	training's binary_logloss: 0.197677	valid_1's auc: 0.684702	valid_1's binary_logloss: 0.215965
# [886]	training's auc: 0.801891	training's binary_logloss: 0.197658	valid_1's auc: 0.6847	valid_1's binary_logloss: 0.215964
# [887]	training's auc: 0.802018	training's binary_logloss: 0.197639	valid_1's auc: 0.684734	valid_1's binary_logloss: 0.215961
# [888]	training's auc: 0.80214	training's binary_logloss: 0.197618	valid_1's auc: 0.684743	valid_1's binary_logloss: 0.215959
# [889]	training's auc: 0.802215	training's binary_logloss: 0.197598	valid_1's auc: 0.684722	valid_1's binary_logloss: 0.215961
# [890]	training's auc: 0.802281	training's binary_logloss: 0.19758	valid_1's auc: 0.684727	valid_1's binary_logloss: 0.215958
# [891]	training's auc: 0.802375	training's binary_logloss: 0.197559	valid_1's auc: 0.684746	valid_1's binary_logloss: 0.215957
# [892]	training's auc: 0.80245	training's binary_logloss: 0.197538	valid_1's auc: 0.684761	valid_1's binary_logloss: 0.215954
# [893]	training's auc: 0.80256	training's binary_logloss: 0.197517	valid_1's auc: 0.684781	valid_1's binary_logloss: 0.215952
# [894]	training's auc: 0.802651	training's binary_logloss: 0.197498	valid_1's auc: 0.684775	valid_1's binary_logloss: 0.21595
# [895]	training's auc: 0.802748	training's binary_logloss: 0.197476	valid_1's auc: 0.684782	valid_1's binary_logloss: 0.215948
# [896]	training's auc: 0.80282	training's binary_logloss: 0.197457	valid_1's auc: 0.684759	valid_1's binary_logloss: 0.215951
# [897]	training's auc: 0.802952	training's binary_logloss: 0.197436	valid_1's auc: 0.6847	valid_1's binary_logloss: 0.21596
# [898]	training's auc: 0.80308	training's binary_logloss: 0.197416	valid_1's auc: 0.684658	valid_1's binary_logloss: 0.215966
# [899]	training's auc: 0.803171	training's binary_logloss: 0.197397	valid_1's auc: 0.684653	valid_1's binary_logloss: 0.21597
# [900]	training's auc: 0.8033	training's binary_logloss: 0.197375	valid_1's auc: 0.684634	valid_1's binary_logloss: 0.215974
# [901]	training's auc: 0.803337	training's binary_logloss: 0.197368	valid_1's auc: 0.684636	valid_1's binary_logloss: 0.215974
# Early stopping, best iteration is:
# [801]	training's auc: 0.794271	training's binary_logloss: 0.199193	valid_1's auc: 0.684836	valid_1's binary_logloss: 0.21594
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=0.8,
#                importance_type='split', learning_rate=0.015, max_depth=10,
#                min_child_samples=300, min_child_weight=0.001,
#                min_split_gain=0.1, n_estimators=2000, n_jobs=-1, num_leaves=51,
#                objective='binary', random_state=None, reg_alpha=0.12,
#                reg_lambda=0.28, silent=True, subsample=0.75,
#                subsample_for_bin=200000, subsample_freq=2)

# %% [markdown]
# ### 测试集预测

# %%
prob = model.predict_proba(test_data)
submission['prob'] = pd.Series(prob[:,1])
submission.drop(['origin'], axis=1, inplace=True)
submission.to_csv('prediction.csv', index=False)
